# %% [markdown]
# #Task 1

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# #Task 2

# %%
import os 
os.getcwd()
# Out:
# '/content'

# %%
cd_file = pd.read_csv('carAuction.csv')

# %%
cd_file.describe()
# Out:
#        MMRCurrentAuctionAveragePrice      VehBCost  ...         VehOdo  WarrantyCost
# count                   10000.000000  10000.000000  ...   10000.000000  10000.000000
# mean                     6116.216000   6720.207200  ...   71541.084100   1279.954000
# std                      2426.340132   1753.796382  ...   14688.317704    609.026443
# min                         0.000000    225.000000  ...    4825.000000    462.000000
# 25%                      4255.000000   5435.000000  ...   61842.500000    834.000000
# 50%                      6076.000000   6700.000000  ...   73506.500000   1169.000000
# 75%                      7732.000000   7880.000000  ...   82462.500000   1623.000000
# max                     27543.000000  29795.000000  ...  109734.000000   5913.000000
#
# [8 rows x 5 columns]

# %% [markdown]
# Describe function displays summary statistics for all columns that it can. For example, how many rows in your table, how many data points are there, mean values, standard deviation, minimum, what's the first quartile, median, etc.

# %%
cd_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Auction                        10000 non-null  object
#  1   Color                          10000 non-null  object
#  2   IsBadBuy                       10000 non-null  object
#  3   MMRCurrentAuctionAveragePrice  10000 non-null  int64
#  4   Size                           10000 non-null  object
#  5   TopThreeAmericanName           10000 non-null  object
#  6   VehBCost                       10000 non-null  int64
#  7   VehicleAge                     10000 non-null  int64
#  8   VehOdo                         10000 non-null  int64
#  9   WarrantyCost                   10000 non-null  int64
#  10  WheelType                      10000 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 859.5+ KB

# %% [markdown]
# Are there any null values in the dataframe? - There is no null values.

# %% [markdown]
# How many columns are there in the dataframe? - 11

# %% [markdown]
# How many rows are there in the dataframe? - 10000

# %% [markdown]
# What datatypes are in the dataframe? - integer and string

# %% [markdown]
# How many columns are associated with each datatype? - 6 are string, 5 are integer

# %% [markdown]
# #Task 3

# %%
cd_file.shape
# Out:
# (10000, 11)

# %%
number_of_rows = cd_file.shape[0]

# %%
print("number_of_rows:",number_of_rows)
# Out:
# number_of_rows: 10000

# %%
number_of_columns = cd_file.shape[1]

# %%
print("number_of_columns:",number_of_columns)
# Out:
# number_of_columns: 11

# %% [markdown]
# #Task 4

# %%
cd_file.head(15)
# Out:
#    Auction   Color IsBadBuy  ...  VehOdo WarrantyCost WheelType
# 0    ADESA   WHITE       No  ...   75419          869     Alloy
# 1    ADESA    GOLD      Yes  ...   82944         2322     Alloy
# 2    ADESA     RED       No  ...   57338          588     Alloy
# 3    ADESA    GOLD       No  ...   55909         1169     Alloy
# 4    ADESA    GREY       No  ...   86702          853     Alloy
# 5    ADESA  SILVER       No  ...   73810         1455    Covers
# 6    ADESA     RED       No  ...   85003         1633    Covers
# 7    ADESA  SILVER       No  ...   88991         2152    Covers
# 8    ADESA  SILVER       No  ...   80077         1373     Alloy
# 9    ADESA  MAROON       No  ...   71952         1272     Alloy
# 10   ADESA   WHITE       No  ...   23881          462    Covers
# 11   ADESA    GOLD       No  ...   83238         5392     Alloy
# 12   ADESA  SILVER       No  ...   68165          728    Covers
# 13   ADESA   GREEN       No  ...   93346         1774     Alloy
# ...

# %%
cd_file['over_80k_miles'] = np.where(cd_file.VehOdo>=80000,True,False)

# %%
cd_file.head(15)
# Out:
#    Auction   Color IsBadBuy  ...  WarrantyCost WheelType over_80k_miles
# 0    ADESA   WHITE       No  ...           869     Alloy          False
# 1    ADESA    GOLD      Yes  ...          2322     Alloy           True
# 2    ADESA     RED       No  ...           588     Alloy          False
# 3    ADESA    GOLD       No  ...          1169     Alloy          False
# 4    ADESA    GREY       No  ...           853     Alloy           True
# 5    ADESA  SILVER       No  ...          1455    Covers          False
# 6    ADESA     RED       No  ...          1633    Covers           True
# 7    ADESA  SILVER       No  ...          2152    Covers           True
# 8    ADESA  SILVER       No  ...          1373     Alloy           True
# 9    ADESA  MAROON       No  ...          1272     Alloy          False
# 10   ADESA   WHITE       No  ...           462    Covers          False
# 11   ADESA    GOLD       No  ...          5392     Alloy           True
# ...

# %%
cd_file_filtered = cd_file.loc[cd_file['over_80k_miles']==True]

# %%
cd_file_filtered
# Out:
#      Auction   Color IsBadBuy  ...  WarrantyCost WheelType over_80k_miles
# 1      ADESA    GOLD      Yes  ...          2322     Alloy           True
# 4      ADESA    GREY       No  ...           853     Alloy           True
# 6      ADESA     RED       No  ...          1633    Covers           True
# 7      ADESA  SILVER       No  ...          2152    Covers           True
# 8      ADESA  SILVER       No  ...          1373     Alloy           True
# ...      ...     ...      ...  ...           ...       ...            ...
# 9988   ADESA   GREEN       No  ...          1243     Alloy           True
# 9989   ADESA    GREY       No  ...          1503    Covers           True
# 9995   ADESA     RED       No  ...           983     Alloy           True
# 9996   ADESA   BLACK       No  ...          1543     Alloy           True
# 9999   ADESA  SILVER       No  ...          1243     Alloy           True
#
# [3162 rows x 12 columns]

# %%
cd_file.sort_values(by=['VehOdo'],ascending=False)
# Out:
#       Auction   Color IsBadBuy  ...  WarrantyCost   WheelType over_80k_miles
# 798   MANHEIM    GREY       No  ...          1130       Alloy           True
# 7174  MANHEIM    GOLD       No  ...          1430      Covers           True
# 7167  MANHEIM  SILVER      Yes  ...          3191       Alloy           True
# 1341  MANHEIM   BLACK       No  ...          1930       Alloy           True
# 9914    ADESA  SILVER       No  ...           650      Covers           True
# ...       ...     ...      ...  ...           ...         ...            ...
# 6894  MANHEIM   BLACK       No  ...           582      Covers          False
# 718   MANHEIM  SILVER       No  ...           882      Covers          False
# 4168  MANHEIM   WHITE      Yes  ...           882       Alloy          False
# 8359  MANHEIM   BLACK      Yes  ...          1694       Alloy          False
# 4472    OTHER    GREY      Yes  ...           642  unkwnWheel          False
#
# [10000 rows x 12 columns]

# %% [markdown]
# #Task 5

# %%
cd_file.boxplot(column='VehOdo')

# %%
cd_file['VehOdo'].describe()
# Out:
# count     10000.000000
# mean      71541.084100
# std       14688.317704
# min        4825.000000
# 25%       61842.500000
# 50%       73506.500000
# 75%       82462.500000
# max      109734.000000
# Name: VehOdo, dtype: float64

# %% [markdown]
# We can see the maximum is about 109734, and this is the line at the top. The minimum is about 4825, and this is the line at the bottom.
# The bottom of the box is the 25% otherwise known as the first quartile. The top of the box is the 75% known as the third quartile, and the middle of the box which is highlighted in green is the median, the 50%, second quartile.

# %%
cd_file['VehOdo'].value_counts()
# Out:
# 65321    5
# 71367    4
# 71823    4
# 85302    4
# 80601    4
#         ..
# 86455    1
# 68028    1
# 82365    1
# 39358    1
# 96822    1
# Name: VehOdo, Length: 9066, dtype: int64

# %%
cd_file['Size'].value_counts().plot(kind='bar')

# %% [markdown]
# Medium has the most values, and the least is Sports.

# %%
cd_file.hist(column='WarrantyCost')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f08d6a58ed0>]],
#       dtype=object)

# %%
cd_file.hist(column='WarrantyCost',bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f08caa15a10>]],
#       dtype=object)

# %% [markdown]
# I changed the bins to 100, that way I could have the detailed look. The WarrantyCost costs around 500 and 2000 the most.

# %%
cd_file_condensed = cd_file[['MMRCurrentAuctionAveragePrice','Size','VehicleAge','WarrantyCost','VehOdo','VehBCost','TopThreeAmericanName','IsBadBuy']]

# %%
cd_file_condensed
# Out:
#       MMRCurrentAuctionAveragePrice         Size  ...  TopThreeAmericanName  IsBadBuy
# 0                              2871  LARGE TRUCK  ...                  FORD        No
# 1                              1840          VAN  ...                  FORD       Yes
# 2                              8931    SMALL SUV  ...              CHRYSLER        No
# 3                              8320    CROSSOVER  ...                  FORD        No
# 4                             11520  LARGE TRUCK  ...                  FORD        No
# ...                             ...          ...  ...                   ...       ...
# 9995                           7536    SMALL SUV  ...              CHRYSLER        No
# 9996                           4921  LARGE TRUCK  ...                    GM        No
# 9997                           9263   MEDIUM SUV  ...              CHRYSLER        No
# 9998                           3240       MEDIUM  ...                 OTHER        No
# ...

# %%
sns.pairplot(data=cd_file_condensed)

# %% [markdown]
# *  'MMRCurrentAuctionAveragePrice' = continuous
# *  'VehicleAge'=continuous
# *  'WarrantyCost'=continuous
# *  'Size'=categorical
# *  'VehOdo'=continuous
# *  'VehBCost'=continuous
# *  'TopThreeAmericanName'=categorical
# *  'IsBadBuy'=categorical

# %%
sns.pairplot(data=cd_file_condensed,hue='IsBadBuy')

# %% [markdown]
# When you see the first plot, you can see the WarrantyCost is on the vertical axis. Blue has much higher counts than yes. A lot more IsBadBuy are not being given with WarrantyCost. As WarrantyCost increases, IsBadBuy tend to go down.
